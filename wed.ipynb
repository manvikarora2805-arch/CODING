# %%
print("hello!")
# Out:
# hello!

# %%
x=23
for i in range(1,11):
     print(x*i)
# Out:
# 23
# 46
# 69
# 92
# 115
# 138
# 161
# 184
# 207
# 230

# %%
for i in range(0,6):
    for j in range(i):
        print("*",end=" ") 
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
